# %%
import pandas as pd
import pygmaps

# %%
dadosbr = 'https://raw.githubusercontent.com/kelvins/Municipios-Brasileiros/master/Municipios_Brasileiros.csv'
df = pd.read_csv(dadosbr, sep=';')
df.head()
# Out:
#    Código IBGE     Nome do Município  Código UF   UF         Estado  Latitude  \
# 0      5200050       Abadia de Goiás         52   GO          Goiás -16.75730
# 1      3100104   Abadia dos Dourados         31   MG   Minas Gerais -18.48310
# 2      5200100             Abadiânia         52   GO          Goiás -16.19700
# 3      3100203                Abaeté         31   MG   Minas Gerais -19.15510
# 4      1500107            Abaetetuba         15   PA           Pará  -1.72183
#
#    Longitude
# 0   -49.4412
# 1   -47.3916
# 2   -48.7057
# 3   -45.4444
# 4   -48.8788

# %%
API_KEY = MY_KEY

# %%
icongreen = 'https://bitcoin-obmen.com/i/green-circle.png'
iconred = 'https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png'
icon = iconred
markers=df[['Latitude', 'Longitude']]
labels=df['Nome do Município']
gmap = pygmaps.Map(API_KEY, markers=markers, labels=labels, icon=icon, zoom=5, height='800px', width='100%',
                   title=f'Municípios Brasileiros', show_pegman=False, show_zoomcontrol=False)
    
gmap.show()
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <style>
#         #map {
#             height: 800px;
#             width: 100%;
#         }
#     </style>
#   </head>
#   <body>
#     <h1>Municípios Brasileiros</h1>
#     <div id="map">
#     </div>
#     <script>
#         function initMap() {
#             var map = new google.maps.Map(document.getElementById('map'), {
#                 zoom: 5,
#                 center: {lat: -16.449143738204675, lng: -46.23100263211851},
#                 mapTypeId: "roadmap",
#                 streetViewControl: false,
#                 zoomControl: false
#             });
#             var marker = new google.maps.Marker({
#     position: {
#         lat: -16.7573,
#         lng: -49.4412
#     },
#     map: map,
#     title: " Abadia de Goiás",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -18.4831,
#         lng: -47.3916
#     },
#     map: map,
#     title: " Abadia dos Dourados",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -16.197,
#         lng: -48.7057
#     },
#     map: map,
#     title: " Abadiânia",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -19.1551,
#         lng: -45.4444
#     },
#     map: map,
#     title: " Abaeté",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -1.72183,
#         lng: -48.8788
#     },
#     map: map,
#     title: " Abaetetuba",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -7.34588,
#         lng: -39.0416
#     },
#     map: map,
#     title: " Abaiara",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -13.2488,
#         lng: -41.6619
#     },
#     map: map,
#     title: " Abaíra",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -8.72073,
#         lng: -39.1162
#     },
#     map: map,
#     title: " Abaré",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -23.3049,
#         lng: -50.3133
#     },
#     map: map,
#     title: " Abatiá",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -27.6126,
#         lng: -51.0233
#     },
#     map: map,
#     title: " Abdon Batista",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -4.95333,
#         lng: -48.3933
#     },
#     map: map,
#     title: " Abel Figueiredo",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -26.5716,
#         lng: -52.3229
#     },
#     map: map,
#     title: " Abelardo Luz",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -20.2996,
#         lng: -42.4743
#     },
#     map: map,
#     title: " Abre Campo",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -7.90072,
#         lng: -34.8984
#     },
#     map: map,
#     title: " Abreu e Lima",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -9.62101,
#         lng: -49.1518
#     },
#     map: map,
#     title: " Abreulândia",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -20.359,
#         lng: -43.1439
#     },
#     map: map,
#     title: " Acaiaca",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -4.94714,
#         lng: -47.5004
#     },
#     map: map,
#     title: " Açailândia",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -11.6575,
#         lng: -38.0197
#     },
#     map: map,
#     title: " Acajutiba",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -1.95383,
#         lng: -48.1985
#     },
#     map: map,
#     title: " Acará",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -4.22083,
#         lng: -38.7055
#     },
#     map: map,
#     title: " Acarape",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -2.88769,
#         lng: -40.1183
#     },
#     map: map,
#     title: " Acaraú",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -6.4282,
#         lng: -36.6347
#     },
#     map: map,
#     title: " Acari",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -8.21954,
#         lng: -41.0831
#     },
#     map: map,
#     title: " Acauã",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -31.8665,
#         lng: -54.1615
#     },
#     map: map,
#     title: " Aceguá",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -6.08911,
#         lng: -39.448
#     },
#     map: map,
#     title: " Acopiara",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -15.194,
#         lng: -56.3632
#     },
#     map: map,
#     title: " Acorizal",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -9.82581,
#         lng: -66.8972
#     },
#     map: map,
#     title: " Acrelândia",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -17.396,
#         lng: -50.3749
#     },
#     map: map,
#     title: " Acreúna",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -19.0671,
#         lng: -42.5419
#     },
#     map: map,
#     title: " Açucena",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -21.682,
#         lng: -51.0737
#     },
#     map: map,
#     title: " Adamantina",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -16.4127,
#         lng: -50.1657
#     },
#     map: map,
#     title: " Adelândia",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -21.2325,
#         lng: -49.6451
#     },
#     map: map,
#     title: " Adolfo",
#     icon: "https://eshop.eca.ir/img/redcircle.png.pagespeed.ce.GbuWBUNpkq.png"
# });
# var marker = new google.maps.Marker({
#     position: {
#         lat: -24.6606,
#         lng: -48.9922
#     },
#     map: map,
#     title: " Adr
