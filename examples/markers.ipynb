# %%
import htmlmin
import pandas as pd
from pymaps.pymaps import Map
from pymaps.marker import Marker

# %%
api_key = open('api_key.txt').read().strip()

# %%
data_url = 'https://raw.githubusercontent.com/kelvins/Municipios-Brasileiros/master/Municipios_Brasileiros.csv'
brazilian_cities = pd.read_csv(data_url, sep=';', converters={'Latitude': float, 'Longitude': float})
print(brazilian_cities.shape)
brazilian_cities.head()
# Out:
# (5570, 7)
#    Código IBGE     Nome do Município  Código UF   UF         Estado  Latitude  \
# 0      5200050       Abadia de Goiás         52   GO          Goiás -16.75730
# 1      3100104   Abadia dos Dourados         31   MG   Minas Gerais -18.48310
# 2      5200100             Abadiânia         52   GO          Goiás -16.19700
# 3      3100203                Abaeté         31   MG   Minas Gerais -19.15510
# 4      1500107            Abaetetuba         15   PA           Pará  -1.72183
#
#    Longitude
# 0   -49.4412
# 1   -47.3916
# 2   -48.7057
# 3   -45.4444
# 4   -48.8788

# %%
brazilian_cities = brazilian_cities.dropna()
print(brazilian_cities.shape)
points = brazilian_cities[['Latitude', 'Longitude']].values.tolist()
# Out:
# (5570, 7)

# %%
map = Map([-15, -47], api_key=api_key, zoom_start=5)
#brazilian_cities.apply(func=lambda x: Marker([x.Latitude, x.Longitude], opacity=1).add_to(map), axis=1)
for i in points[:4400]:    
    Marker(i).add_to(map)

# %%
map
# Out:
# <iframe src="data:text/html;charset=utf-8;base64,..." style="height:500px;width:100%;border:none !important"></iframe>

# %%
from css_html_js_minify import html_minify, js_minify, css_minify
minified = js_minify(map.html)
minified
# Out:
# '<!DOCTYPE html><html><head><style>#map{height:500px;}html,body{height:100%;margin:0;padding:0;}</style></head><body><div id="map"><!--Map will be placed here--></div><script>function initMap(){var map=new google.maps.Map(document.getElementById(\'map\'),{zoom:5,center:{lat:-15,lng:-47},mapTypeId:\'roadmap\',streetViewControl:1,zoomControl:1,disableDefaultUI:0,});var marker=new google.maps.Marker({position:{lat:-16.7573,lng:-49.4412},draggable:false,map:map,title:"",label:"",animation:null,icon:null,opacity:1,optimized:true});var marker=new google.maps.Marker({position:{lat:-18.4831,lng:-47.3916},draggable:false,map:map,title:"",label:"",animation:null,icon:null,opacity:1,optimized:true});var marker=new google.maps.Marker({position:{lat:-16.197,lng:-48.7057},draggable:false,map:map,title:"",label:"",animation:null,icon:null,opacity:1,optimized:true});var marker=new google.maps.Marker({position:{lat:-19.1551,lng:-45.4444},draggable:false,map:map,title:"",label:"",animation:null,icon:n
# ...

# %%
from IPython.display import HTML
HTML(minified)
# Out:
# <!DOCTYPE html><html><head><style>#map{height:500px;}html,body{height:100%;margin:0;padding:0;}</style></head><body><div id="map"><!--Map will be placed here--></div><script>function initMap(){var map=new google.maps.Map(document.getElementById('map'),{zoom:5,center:{lat:-15,lng:-47},mapTypeId:'roadmap',streetViewControl:1,zoomControl:1,disableDefaultUI:0,});var marker=new google.maps.Marker({position:{lat:-16.7573,lng:-49.4412},draggable:false,map:map,title:"",label:"",animation:null,icon:null,opacity:1,optimized:true});var marker=new google.maps.Marker({position:{lat:-18.4831,lng:-47.3916},draggable:false,map:map,title:"",label:"",animation:null,icon:null,opacity:1,optimized:true});var marker=new google.maps.Marker({position:{lat:-16.197,lng:-48.7057},draggable:false,map:map,title:"",label:"",animation:null,icon:null,opacity:1,optimized:true});var marker=new google.maps.Marker({position:{lat:-19.1551,lng:-45.4444},draggable:false,map:map,title:"",label:"",animation:null,icon:null,o
# ...
